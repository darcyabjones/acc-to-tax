# %%
from importlib import reload

import acc2tax.database
reload(acc2tax.database)

from acc2tax.database import create_session
from acc2tax.database import Base
from acc2tax.database import Nodes
from acc2tax.database import Names
from acc2tax.database import Division

# %%
db = "sqlite:///:memory:"

session, engine = create_session(target=db)

# %%
Base.session = session
Base.metadata.create_all(engine)

# %%
Nodes.session

# %%
Nodes.from_file("/home/darcyabjones/data/sequence_databases/data/ncbi_taxonomy/nodes.dmp", session)

# %%
Names.from_file("/home/darcyabjones/data/sequence_databases/data/ncbi_taxonomy/names.dmp", session)

# %%
Division.from_file("/home/darcyabjones/data/sequence_databases/data/ncbi_taxonomy/division.dmp", session)

# %%
#Nodes.filter(Nodes.taxid == 1656094, session=session).all()
Nodes.query("taxid").filter(Nodes.taxid == 1656094).one()
# Out:
# (1656094)

# %%
session.query(Nodes.taxid, Nodes.parent_taxid).filter(Nodes.taxid == 1656094).all()
# Out:
# [(1656094, 226)]

# %%
Nodes.query(["taxid", "parent_taxid"]).filter(Nodes.taxid == 1656094).one()
# Out:
# (1656094, 226)

# %%
Nodes.filter(Nodes.taxid == 1656094).one()
# Out:
# Nodes(taxid=1656094, parent_taxid=226, rank='species', embl_code='AC', division_id=0, inherited_div_flag=True, genetic_code_id='11', inherited_genetic_code_flag=True, mitochonchondrial_genetic_code_id='0', inherited_mitochonchondrial_genetic_code_flag=True, genbank_hidden_flag=True, hidden_subtree_root_flag=True, comments='')

# %%
Nodes.get_records("taxid", [1656094])
# Out:
# [Nodes(taxid=1656094, parent_taxid=226, rank='species', embl_code='AC', division_id=0, inherited_div_flag=True, genetic_code_id='11', inherited_genetic_code_flag=True, mitochonchondrial_genetic_code_id='0', inherited_mitochonchondrial_genetic_code_flag=True, genbank_hidden_flag=True, hidden_subtree_root_flag=True, comments='')]

# %%
Nodes.get_record("taxid", 1656094)
# Out:
# Nodes(taxid=1656094, parent_taxid=226, rank='species', embl_code='AC', division_id=0, inherited_div_flag=True, genetic_code_id='11', inherited_genetic_code_flag=True, mitochonchondrial_genetic_code_id='0', inherited_mitochonchondrial_genetic_code_flag=True, genbank_hidden_flag=True, hidden_subtree_root_flag=True, comments='')

# %%
x = Nodes.get_taxids([1656094, 1396, 28901])

# %%
[n.taxid for n in Nodes.get_parents([28901])]
# Out:
# [590, 543, 91347, 1236, 1224, 2, 131567, 1]

# %%
Nodes.get_children(x)
# Out:
# [Nodes(taxid=59201, parent_taxid=28901, rank='subspecies', embl_code='SE', division_id=0, inherited_div_flag=True, genetic_code_id='11', inherited_genetic_code_flag=True, mitochonchondrial_genetic_code_id='0', inherited_mitochonchondrial_genetic_code_flag=True, genbank_hidden_flag=True, hidden_subtree_root_flag=True, comments=''),
#  Nodes(taxid=59202, parent_taxid=28901, rank='subspecies', embl_code='SE', division_id=0, inherited_div_flag=True, genetic_code_id='11', inherited_genetic_code_flag=True, mitochonchondrial_genetic_code_id='0', inherited_mitochonchondrial_genetic_code_flag=True, genbank_hidden_flag=True, hidden_subtree_root_flag=True, comments=''),
# ...

# %%
x[0].parents()
# Out:
# [Nodes(taxid=86661, parent_taxid=1386, rank='species group', embl_code='', division_id=0, inherited_div_flag=True, genetic_code_id='11', inherited_genetic_code_flag=True, mitochonchondrial_genetic_code_id='0', inherited_mitochonchondrial_genetic_code_flag=True, genbank_hidden_flag=True, hidden_subtree_root_flag=True, comments=''),
#  Nodes(taxid=1386, parent_taxid=186817, rank='genus', embl_code='', division_id=0, inherited_div_flag=True, genetic_code_id='11', inherited_genetic_code_flag=True, mitochonchondrial_genetic_code_id='0', inherited_mitochonchondrial_genetic_code_flag=True, genbank_hidden_flag=True, hidden_subtree_root_flag=True, comments=''),
#  Nodes(taxid=186817, parent_taxid=1385, rank='family', embl_code='', division_id=0, inherited_div_flag=True, genetic_code_id='11', inherited_genetic_code_flag=True, mitochonchondrial_genetic_code_id='0', inherited_mitochonchondrial_genetic_code_flag=True, genbank_hidden_flag=True, hidden_subtree_root_flag=True, comments=''),
# ...

# %%
print(x[1])
# Out:
# taxid: 28901, parent_taxid: 590, rank: 'species'

# %%
len(Nodes.get_children([1656094, 1396, 28901]))
# Out:
# 3121

# %%
x[2].rank
# Out:
# 'species'

# %%
x[2].names
# Out:
# [Names(taxid=1656094, name='Alteromonas confluentis', unique_name='', name_class='scientific name'),
#  Names(taxid=1656094, name='Alteromonas confluentis Park et al. 2015', unique_name='', name_class='authority'),
#  Names(taxid=1656094, name='Alteromonas sp. DSSK2-12', unique_name='', name_class='includes'),
#  Names(taxid=1656094, name='CECT 8870', unique_name='', name_class='type material'),
#  Names(taxid=1656094, name='KCTC 42603', unique_name='', name_class='type material'),
#  Names(taxid=1656094, name='strain DSSK2-12', unique_name='', name_class='type material')]

# %%
# !zcat /home/darcyabjones/data/sequence_databases/data/ncbi_taxonomy/prot.accession2taxid.gz | head -n 30
# Out:
# accession	accession.version	taxid	gi
# WP_070124587	WP_070124587.1	1656094	1079317924
# WP_070124589	WP_070124589.1	1656094	1079317926
# WP_070124590	WP_070124590.1	28901	1079317927
# WP_070124591	WP_070124591.1	1656094	1079317928
# WP_070124592	WP_070124592.1	28901	1079317929
# WP_070124594	WP_070124594.1	1656094	1079317931
# WP_070124595	WP_070124595.1	28901	1079317932
# WP_070124596	WP_070124596.1	1656094	1079317933
# WP_070124597	WP_070124597.1	1656094	1079317934
# WP_070124598	WP_070124598.1	28901	1079317935
# WP_070124599	WP_070124599.1	1656094	1079317936
# WP_070124600	WP_070124600.1	28901	1079317937
# WP_070124602	WP_070124602.1	1656094	1079317939
# WP_070124603	WP_070124603.1	28901	1079317940
# WP_070124604	WP_070124604.1	1656094	1079317941
# PFQ02028	PFQ02028.1	1396	1262379509
# PFQ02029	PFQ02029.1	1396	1262379510
# PFQ02030	PFQ02030.1	1396	1262379511
# PFQ02031	PFQ02031.1	1396	1262379512
# PFQ02032	PFQ02032.1	1396	1262379513
# PFQ02033	PFQ02033.1	1396	1262379514
# ...

# %%
sample_nodes = Nodes.get_parents([1656094, 1396, 28901], session)

# %%
Names.get_taxids(1656094, name_class="scientific name")
# Out:
# [Names(taxid=1656094, name='Alteromonas confluentis', unique_name='', name_class='scientific name')]

# %%
??sqlalchemy.orm.Query
# Out:
# Object `sqlalchemy.orm.Query` not found.

# %%
seen = set()
d = list()
for n in sample_nodes:
    if n.taxid in seen:
        continue
    
    seen.add(n.taxid)
    d.append(n)

sample_nodes = sorted(d, key=lambda x: getattr(x, "taxid"))
del d

# %%
with open("sample_nodes.dmp", "w") as handle:
    handle.write(''.join(Nodes.to_string(sample_nodes)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-b2bf51b35529> in <module>()
#       1 with open("sample_nodes.dmp", "w") as handle:
# ----> 2     handle.write(''.join(Nodes.to_string(sample_nodes)))
#
# AttributeError: type object 'Nodes' has no attribute 'to_string'

# %%
# !head -n 6 sample_nodes.dmp

# %%
sample_names = list()
for node in sample_nodes:
    sample_names.extend(node.names)

# %%
with open("sample_names.dmp", "w") as handle:
    handle.write(''.join(Names.to_string(sample_names)))

# %%
# !head -n 6 sample_names.dmp

# %%
seen = set()
sample_divisions = list()
for node in sample_nodes:
    if node.division_id in seen:
        continue
    seen.add(node.division_id)
    sample_divisions.append(node.division)

# %%
with open("sample_division.dmp", "w") as handle:
    handle.write(''.join(Division.to_string(sample_divisions)))

# %%
# !cat sample_division.dmp

# %%
from unittest.mock import MagicMock

# %%
x = MagicMock(a=1, b=2)

# %%
x.b

# %%
from collections import Iterable

# %%
x = set()

# %%
x.update([1,2,3])

# %%
import pandas as pd

# %%
print(pd.DataFrame())

# %%
from sqlalchemy.orm import Session
??Session
